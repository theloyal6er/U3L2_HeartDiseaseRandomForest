# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_path = ('/Users/Jason Paik/My Documents/Data Science/HeartDisease.csv')

# %%
dataraw = pd.read_csv(data_path)

# %%
dataraw.head()
# Out:
#    Age  Sex  ChestPain  RestingBP  Cholestoral  BloodSugar  ECGResults  \
# 0   63    1          3        145          233           1           0
# 1   37    1          2        130          250           0           1
# 2   41    0          1        130          204           0           0
# 3   56    1          1        120          236           0           1
# 4   57    0          0        120          354           0           1
#
#    MaxHeartRate  ExerciseInducedAngina  OldPeak  SlopePeak  MajorVessels  \
# 0           150                      0      2.3          0             0
# 1           187                      0      3.5          0             0
# 2           172                      0      1.4          2             0
# 3           178                      0      0.8          2             0
# 4           163                      1      0.6          2             0
#
#    Thalassemia  Target
# 0            1       1
# 1            2       1
# 2            2       1
# ...

# %%
dataraw.columns = ['Age','Sex','ChestPain','RestingBP','Cholestoral','BloodSugar','ECGResults','MaxHeartRate',
                      'ExerciseInducedAngina','OldPeak','SlopePeak','MajorVessels','Thalassemia','Target']

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(dataraw.corr(),cmap="YlGnBu")

# %%
dataraw_1 = dataraw

# %%
dataraw_1.head()
# Out:
#    Age  Sex  ChestPain  RestingBP  Cholestoral  BloodSugar  ECGResults  \
# 0   63    1          3        145          233           1           0
# 1   37    1          2        130          250           0           1
# 2   41    0          1        130          204           0           0
# 3   56    1          1        120          236           0           1
# 4   57    0          0        120          354           0           1
#
#    MaxHeartRate  ExerciseInducedAngina  OldPeak  SlopePeak  MajorVessels  \
# 0           150                      0      2.3          0             0
# 1           187                      0      3.5          0             0
# 2           172                      0      1.4          2             0
# 3           178                      0      0.8          2             0
# 4           163                      1      0.6          2             0
#
#    Thalassemia  Target
# 0            1       1
# 1            2       1
# 2            2       1
# ...

# %%
from sklearn import ensemble
from sklearn.model_selection import cross_val_score

rfc = ensemble.RandomForestClassifier()
X = dataraw_1.drop('Target', 1)
Y = dataraw_1['Target']
X = pd.get_dummies(X)
X = X.dropna(axis=1)

cross_val_score(rfc, X, Y, cv=10)
# Out:
# array([0.90322581, 0.80645161, 0.87096774, 0.83870968, 0.83870968,
#        0.73333333, 0.7       , 0.86666667, 0.75862069, 0.86206897])

# %%
dataraw_2 = dataraw
dataraw_3 = dataraw
dataraw_4 = dataraw

# %%
dataraw_2 = dataraw[['ChestPain','ECGResults','MaxHeartRate','Cholestoral','SlopePeak','Target']]
rfc1 = ensemble.RandomForestClassifier()
X1 = dataraw_2.drop('Target', 1)
Y1 = dataraw_2['Target']
X1 = pd.get_dummies(X1)
X1 = X1.dropna(axis=1)

cross_val_score(rfc1, X1, Y1, cv=10)
# Out:
# array([0.70967742, 0.70967742, 0.58064516, 0.74193548, 0.74193548,
#        0.63333333, 0.7       , 0.76666667, 0.48275862, 0.72413793])

# %%
dataraw_3 = dataraw[['ChestPain','MaxHeartRate','ECGResults','SlopePeak','Target']]
rfc2 = ensemble.RandomForestClassifier()
X2 = dataraw_3.drop('Target', 1)
Y2 = dataraw_3['Target']
X2 = pd.get_dummies(X2)
X2 = X2.dropna(axis=1)

cross_val_score(rfc2, X2, Y2, cv=10)
# Out:
# array([0.74193548, 0.70967742, 0.74193548, 0.58064516, 0.61290323,
#        0.66666667, 0.7       , 0.73333333, 0.62068966, 0.68965517])

# %%
dataraw_4 = dataraw[['Age','Sex','MajorVessels','Thalassemia','Target']]
rfc3 = ensemble.RandomForestClassifier()
X3 = dataraw_3.drop('Target', 1)
Y3 = dataraw_3['Target']
X3 = pd.get_dummies(X3)
X3 = X.dropna(axis=1)

cross_val_score(rfc3, X3, Y3, cv=10)
# Out:
# array([0.80645161, 0.77419355, 0.83870968, 0.93548387, 0.93548387,
#        0.76666667, 0.83333333, 0.86666667, 0.65517241, 0.82758621])

# %%
dataraw_1.head(100)
# Out:
#     Age  Sex  ChestPain  RestingBP  Cholestoral  BloodSugar  ECGResults  \
# 0    63    1          3        145          233           1           0
# 1    37    1          2        130          250           0           1
# 2    41    0          1        130          204           0           0
# 3    56    1          1        120          236           0           1
# 4    57    0          0        120          354           0           1
# 5    57    1          0        140          192           0           1
# 6    56    0          1        140          294           0           0
# 7    44    1          1        120          263           0           1
# 8    52    1          2        172          199           1           1
# 9    57    1          2        150          168           0           1
# 10   54    1          0        140          239           0           1
# 11   48    0          2        130          275           0           1
# ...
